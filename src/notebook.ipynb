# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Vivobook\Documents\Proyectos\Geokam\src

# %%
base_master = pd.read_csv("../data/master_base.csv")

# %%
base_master.head(4)
# Out:
#                                         sk_direccion
# 0  829b8f0f9983e36986cbe1f21a4491db36d8909d9d17e8...  \
# 1  358ada37a4bf426ec3e2823df5f70aec1cc7efc6187055...
# 2  d5d3aa0f66fdcbab5995669fe82d9af34faae6ab9b1ad1...
# 3  50109884fa67713c9add8226d65ea7ad949b7491273d67...
#
#                                          sk_comercio  num_documento
# 0  0011981bba58756ab9dd03a54411f24928cd213af081a2...    20612070521  \
# 1  00681447fe6ee8d0c13a0cad5d6147d94cc22c05421b21...    10433670596
# 2  0071992a36efd80f0710aa15fd2c8ace75819d8e3f780a...    20613390821
# 3  0090ddc94c34b3c577303b9e3cf2a2d7f8b02210c29ef4...    20445542327
#
#                             grupo_economico                kam
# 0                        ORIENTAL X1 S.A.C.        JORGE CALLE  \
# 1         VICENTE HERRERA ELIZABETH ARACELY  ANABEL SANTAMARIA
# 2  EL SATELITE DISTRIBUIDORMAYORISTA S.A.C.   FIORELLA TENORIO
# 3                   INVERSIONES CUBA S.R.L.       DANIEL LOVON
#
# ...
